# %%
# 1. extract video_id, topic_id and category_id, tags
# 2. replace topic_id missing value to NA
# 3. replace tags missing value to "NA"


asso_df = df[["video_id", "topic_id", "category_id", "tags"]]


asso_df.loc[asso_df.topic_id.isnull(), 'topic_id'] = "NA"

asso_df

asso_df.to_csv(f"upload_to_azure/US_association_rule.csv", encoding='utf-8', index=False)

# %%
import os
from datetime import datetime
#import isodate
import pandas as pd
import numpy as np

# %%
# config, select country 
COUNTRY_CODE = 'US'

# read data frame
df = pd.read_csv(f"final_dataset/{COUNTRY_CODE}videos.csv", parse_dates=["publish_time"])

df['trending_date'] = pd.to_datetime(df['trending_date'])
# 2018-06-12T03:11:18.000Z
df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
print(f"How many rows in { COUNTRY_CODE } table? { len(df) }")
print(f"How many unique videos in { COUNTRY_CODE } table? { len(df.video_id.unique() )}")
# Out:
# How many rows in US table? 47133
# How many unique videos in US table? 7323

# %%
# first row of the table as a sample
df.tail(3)
# Out:
#           video_id  duration topic_id trending_date  \
# 47130  zy0b9e40tK8       NaN      NaN    2017-11-14
# 47131  zzQsGL_F9_c       NaN      NaN    2018-02-05
# 47132  zzQsGL_F9_c       NaN      NaN    2018-02-06
#
#                                         title channel_title  category_id  \
# 47130  Dark | Official Trailer [HD] | Netflix       Netflix           24
# 47131          Budweiser | Beer Country | :60     Budweiser           24
# 47132          Budweiser | Beer Country | :60     Budweiser           24
#
#                    publish_time  \
# 47130 2017-11-09 09:00:07+00:00
# 47131 2018-01-30 18:30:04+00:00
# 47132 2018-01-30 18:30:04+00:00
#
#                                                     tags   views  likes  \
# 47130  Netflix|Baran Bo Odar|Jantje Friese|DARK|darkm...  378750   5642
# 47131  Budweiser|Super Bowl|Clydesdales|Bud|This Buds...  154206   1180
# 47132  Budweiser|Super Bowl|Clydesdales|Bud|This Buds...  199041   1415
#
#        dislikes  comment_count  \
# 47130       146            675
# 47131       107             55
# 47132       121             62
#
#                                        thumbnail_link  comments_disabled  \
# 47130  https://i.ytimg.com/vi/zy0b9e40tK8/default.jpg              False
# 47131  https://i.ytimg.com/vi/zzQsGL_F9_c/default.jpg              False
# 47132  https://i.ytimg.com/vi/zzQsGL_F9_c/default.jpg              False
#
#        ratings_disabled video_error_or_removed  \
# 47130             False                  False
# 47131             False                  False
# 47132             False                  False
#
#                                              description channel_id
# 47130  The disappearance of two kids in the German sm...        NaN
# 47131  This is a story bigger than beer. It’s a story...        NaN
# 47132  This is a story bigger than beer. It’s a story...        NaN

# %%
# the name of the columns and what type of data the columns contain
df.dtypes
# Out:
# video_id                               object
# duration                              float64
# topic_id                               object
# trending_date                  datetime64[ns]
# title                                  object
# channel_title                          object
# category_id                             int64
# publish_time              datetime64[ns, UTC]
# tags                                   object
# views                                   int64
# likes                                   int64
# dislikes                                int64
# comment_count                           int64
# thumbnail_link                         object
# comments_disabled                        bool
# ratings_disabled                         bool
# video_error_or_removed                 object
# description                            object
# channel_id                             object
# dtype: object

# %%
# VIDEO DURATION (in seconds)

privatized_videos = df[df.duration.isnull()]
print(f"How many privatized / deleted videos entries (NOT UNIQUE) in {COUNTRY_CODE} dataset?", len(privatized_videos))
print(f"How many privatized / deleted videos (UNIQUE) in {COUNTRY_CODE} dataset?", len(privatized_videos.video_id.unique()))

df[["duration"]].describe()
# Out:
# How many privatized / deleted videos entries (NOT UNIQUE) in US dataset? 3968
# How many privatized / deleted videos (UNIQUE) in US dataset? 363
#             duration
# count   43165.000000
# mean      630.235306
# std      8235.531462
# min         0.000000
# 25%       184.000000
# 50%       303.000000
# 75%       619.000000
# max    842151.000000

# %%
# TOPIC_ID
# the missing value part is the same to video duration
# they both only exist in 2019 new data
# and YouTube doesn't allow us to query privatized/deleted videos

print(f"How many NA values in topic_id column?", len(df[df.topic_id.isnull()]))
print(f"How many videos missing topic_id?", len(df[df.topic_id.isnull()].video_id.unique()))
# Out:
# How many NA values in topic_id column? 4415
# How many videos missing topic_id? 427

# %%
# topic reference list
topic_id_reference = pd.read_csv("reference/topic_ids.csv", names=["topic_id", "topic_text"], header=None)
topic_id_reference
# Out:
#       topic_id                        topic_text
# 0     /m/04rlf                             Music
# 1    /m/05fw6t                  Children's music
# 2    /m/02mscn                   Christian music
# 3    /m/0ggq0m                   Classical music
# 4     /m/01lyv                           Country
# 5     /m/02lkt                  Electronic music
# 6   /m/0glt670                     Hip hop music
# 7    /m/05rwpb                 Independent music
# 8     /m/03_d0                              Jazz
# 9    /m/028sqc                     Music of Asia
# 10    /m/0g293            Music of Latin America
# 11    /m/064t9                         Pop music
# 12    /m/06cqb                            Reggae
# 13    /m/06j6l                  Rhythm and blues
# 14    /m/06by7                        Rock music
# 15    /m/0gywn                        Soul music
# 16   /m/0bzvm2                            Gaming
# 17   /m/025zzc                       Action game
# 18   /m/02ntfj             Action-adventure game
# 19   /m/0b1vjn                       Casual game
# 20   /m/02hygl                  Music video game
# 21  /m/04q1x3q                 Puzzle video game
# 22   /m/01sjng                 Racing video game
# 23  /m/0403l3g           Role-playing video game
# 24   /m/021bp2             Simulation video game
# 25   /m/022dc6                       Sports game
# 26  /m/03hf_rm               Strategy video game
# 27    /m/06ntj                            Sports
# 28     /m/0jm_                 American football
# 29    /m/018jz                          Baseball
# 30    /m/018w8                        Basketball
# 31    /m/01cgz                            Boxing
# 32    /m/09xp_                           Cricket
# 33    /m/02vx4                          Football
# 34    /m/037hz                              Golf
# 35    /m/03tmr                        Ice hockey
# 36   /m/01h7lh                Mixed martial arts
# 37  /m/0410tth                        Motorsport
# 38    /m/066wd            Professional wrestling
# 39    /m/07bs0                            Tennis
# 40    /m/07_53                        Volleyball
# 41    /m/02jjt                     Entertainment
# 42    /m/095bb                  Animated cartoon
# 43    /m/09kqc                             Humor
# 44    /m/02vxn                            Movies
# 45    /m/05qjc                   Performing arts
# 46   /m/019_rr                         Lifestyle
# 47    /m/032tl                           Fashion
# 48   /m/027x7n                           Fitness
# 49    /m/02wbm                              Food
# 50    /m/0kt51                            Health
# 51    /m/03glg                             Hobby
# 52    /m/068hy                              Pets
# 53   /m/041xxh  Physical attractiveness [Beauty]
# 54    /m/07c1v                        Technology
# 55    /m/07bxq                           Tourism
# 56    /m/07yv9                          Vehicles
# 57   /m/01k8wb                         Knowledge
# 58    /m/098wr                           Society

# %%
# TRENDING_DATE
old_df = df[df.trending_date < pd.Timestamp('2019-10-01')].sort_values('trending_date')
new_df = df[df.trending_date > pd.Timestamp('2019-10-01')].sort_values('trending_date')

old_start = old_df.head(1).trending_date.to_string(index=False)
old_end = old_df.tail(1).trending_date.to_string(index=False)

new_start = new_df.head(1).trending_date.to_string(index=False)
new_end = new_df.tail(1).trending_date.to_string(index=False)

print(f"Kaggle dataset from: { old_start } to { old_end } ")
print(f"New dataset from: { new_start } to { new_end } ")
# Out:
# Kaggle dataset from: 2017-11-14 to 2018-06-14
# New dataset from: 2019-10-15 to 2019-11-04

# %%
# TITLE

print(f"Missing value in title column: { len(df[df.title.isnull()]) }")
# Out:
# Missing value in title column: 0

# %%
# CHANNEL_TITLE

print(f"Missing value in channel_title column: { len(df[df.channel_title.isnull()]) }")
# Out:
# Missing value in channel_title column: 0

# %%
# CATEGORY_ID

print(f"Missing value in category_id column: { len(df[df.category_id.isnull()]) }")
# Out:
# Missing value in category_id column: 0

# %%
# category_id reference

pd.read_csv("reference/category_ids.csv")
# Out:
#     category_id          category_name  \
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            19        Travel & Events
# 6            20                 Gaming
# 7            22         People & Blogs
# 8            23                 Comedy
# 9            24          Entertainment
# 10           25        News & Politics
# 11           26          Howto & Style
# 12           27              Education
# 13           28   Science & Technology
# 14           29  Nonprofits & Activism
#
#                                       category_detail
# 0   Film category includes new film trailers, vide...
# 1   Autos & Vehicles category includes video relat...
# 2   Music category seems not required any instruct...
# 3   Pets and Animals category includes funny and a...
# 4   Sports category includes videos for sports and...
# 5   Travel & Events category includes videos for t...
# 6   Gaming category includes videos for games, gam...
# 7   Category includes videos for people, life styl...
# 8   Comedy category includes comedy videos in diff...
# 9   Entertainment category have videos for enterta...
# 10  Again category it self explain which kind of v...
# 11  Videos which have how to tutorials, style, fas...
# 12  Education category includes videos for eductio...
# 13  Videos which have content for Science and Tech...
# 14  Nonprofits & Activism category includes videos...

# %%
# PUBLISH_TIME
old_df = df[df.publish_time < pd.Timestamp('2019-10-01', tz='UTC')].sort_values('publish_time')
new_df = df[df.publish_time > pd.Timestamp('2019-10-01', tz='UTC')].sort_values('publish_time')

old_start = old_df.head(1).trending_date.to_string(index=False)
old_end = old_df.tail(1).trending_date.to_string(index=False)

new_start = new_df.head(1).trending_date.to_string(index=False)
new_end = new_df.tail(1).trending_date.to_string(index=False)

print(f"Kaggle dataset publish_time ranging from: { old_start } to { old_end } ")
print(f"New dataset publish_time ranging from: { new_start } to { new_end } ")
# Out:
# Kaggle dataset publish_time ranging from: 2018-02-05 to 2018-06-14
# New dataset publish_time ranging from: 2019-10-15 to 2019-11-04

# %%
# TAGS

missing_tags = df[df.tags.isnull()]
print(f'How many rows have missing tags? { len(missing_tags) }')
print(f"How many videos miss tags? { len(missing_tags.video_id.unique()) }")

tags_collector = []
for row in df[df.tags.notnull()].tags:
    tags_collector.extend(row.split('|'))

print(f"How many unique tags in total? { len(set(tags_collector)) }")
# Out:
# How many rows have missing tags? 1775
# How many videos miss tags? 296
# How many unique tags in total? 65468

# %%
# VIEWS, LIKES, DISLIKES, COMMENT_COUNT
df[["views", "likes", "dislikes", "comment_count"]].describe()
# Out:
#               views         likes      dislikes  comment_count
# count  4.713300e+04  4.713300e+04  4.713300e+04   4.713300e+04
# mean   2.300286e+06  7.449503e+04  3.637262e+03   8.218892e+03
# std    7.009090e+06  2.243532e+05  2.754915e+04   3.538383e+04
# min    5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    2.632330e+05  5.665000e+03  2.130000e+02   6.410000e+02
# 50%    7.170340e+05  1.916100e+04  6.490000e+02   1.957000e+03
# 75%    1.830129e+06  5.778800e+04  1.937000e+03   5.730000e+03
# max    2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
df[df.likes == 0]
# Out:
#           video_id  duration   topic_id trending_date  \
# 560    PRHVfIbeGpQ      16.0  /m/019_rr    2017-12-14
# 734    _akwfRuL4os     256.0   /m/098wr    2017-11-23
# 735    _akwfRuL4os     256.0   /m/098wr    2017-11-24
# 736    _akwfRuL4os     256.0   /m/098wr    2017-11-25
# 737    _akwfRuL4os     256.0   /m/098wr    2017-11-26
# ...            ...       ...        ...           ...
# 46981  v4DFeT9z7yY       NaN        NaN    2018-02-22
# 46982  v4DFeT9z7yY       NaN        NaN    2018-02-23
# 46983  v4DFeT9z7yY       NaN        NaN    2018-02-24
# 46984  v4DFeT9z7yY       NaN        NaN    2018-02-25
# 47129  zkrq7Kpd1so       NaN        NaN    2018-03-24
#
#                                                    title  \
# 560    How to Write-In for the Alabama Special Electi...
# 734    Highlights of the EA predatory behavior announ...
# 735    Highlights of the EA predatory behavior announ...
# 736    Highlights of the EA predatory behavior announ...
# 737    Highlights of the EA predatory behavior announ...
# ...                                                  ...
# 46981  Camila Cabello Performs 'Never Be the Same' | ...
# 46982  Camila Cabello Performs 'Never Be the Same' | ...
# 46983  Camila Cabello Performs 'Never Be the Same' | ...
# 46984  Camila Cabello Performs 'Never Be the Same' | ...
# 47129  ULTRA LIVE presents Ultra Music Festival 2018 ...
#
#                       channel_title  category_id              publish_time  \
# 560    American Bridge 21st Century           25 2017-12-11 14:54:32+00:00
# 734                       chris lee           22 2017-11-21 19:29:03+00:00
# 735                       Chris Lee           22 2017-11-21 19:29:03+00:00
# 736                       Chris Lee           22 2017-11-21 19:29:03+00:00
# 737                       Chris Lee           22 2017-11-21 19:29:03+00:00
# ...                             ...          ...                       ...
# 46981                Dancing On Ice           24 2018-02-18 19:57:11+00:00
# 46982                Dancing On Ice           24 2018-02-18 19:57:11+00:00
# 46983                Dancing On Ice           24 2018-02-18 19:57:11+00:00
# 46984                Dancing On Ice           24 2018-02-18 19:57:11+00:00
# 47129                        UMF TV           10 2018-03-24 07:55:21+00:00
#
#                                                     tags    views  likes  \
# 560                                                  NaN    22690      0
# 734                                                  NaN   160012      0
# 735                                                  NaN   179448      0
# 736                                                  NaN   187973      0
# 737                                                  NaN   193362      0
# ...                                                  ...      ...    ...
# 46981          dancing on ice|ice skating|camila cabello   593311      0
# 46982          dancing on ice|ice skating|camila cabello   759160      0
# 46983          dancing on ice|ice skating|camila cabello   923299      0
# 46984          dancing on ice|ice skating|camila cabello  1011961      0
# 47129  ultra music festival|umf|mix|relive|after movi...  1648886      0
#
#        dislikes  comment_count  \
# 560           0              0
# 734           0           1722
# 735           0           1847
# 736           0           1919
# 737           0           1958
# ...         ...            ...
# 46981         0              0
# 46982         0              0
# 46983         0              0
# 46984         0              0
# 47129         0            548
#
#                                        thumbnail_link  comments_disabled  \
# 560    https://i.ytimg.com/vi/PRHVfIbeGpQ/default.jpg               True
# 734    https://i.ytimg.com/vi/_akwfRuL4os/default.jpg              False
# 735    https://i.ytimg.com/vi/_akwfRuL4os/default.jpg              False
# 736    https://i.ytimg.com/vi/_akwfRuL4os/default.jpg              False
# 737    https://i.ytimg.com/vi/_akwfRuL4os/default.jpg              False
# ...                                               ...                ...
# 46981  https://i.ytimg.com/vi/v4DFeT9z7yY/default.jpg               True
# 46982  https://i.ytimg.com/vi/v4DFeT9z7yY/default.jpg               True
# 46983  https://i.ytimg.com/vi/v4DFeT9z7yY/default.jpg               True
# 46984  https://i.ytimg.com/vi/v4DFeT9z7yY/default.jpg               True
# 47129  https://i.ytimg.com/vi/zkrq7Kpd1so/default.jpg              False
#
#        ratings_disabled video_error_or_removed  \
# 560                True                  False
# 734                True                  False
# 735                True                  False
# 736                True                  False
# 737                True                  False
# ...                 ...                    ...
# 46981              True                  False
# 46982              True                  False
# 46983              True                  False
# 46984              True                  False
# 47129              True                  False
#
#                                              description channel_id
# 560    Ahead of Tuesday's special election in Alabama...        NaN
# 734    The State of Hawaii announces action to addres...        NaN
# 735    The State of Hawaii announces action to addres...        NaN
# 736    The State of Hawaii announces action to addres...        NaN
# 737    The State of Hawaii announces action to addres...        NaN
# ...                                                  ...        ...
# 46981  Camila Cabello lights up the ice with an amazi...        NaN
# 46982  Camila Cabello lights up the ice with an amazi...        NaN
# 46983  Camila Cabello lights up the ice with an amazi...        NaN
# 46984  Camila Cabello lights up the ice with an amazi...        NaN
# 47129  Tune in here for the Ultra Music Festival 2018...        NaN
#
# [247 rows x 19 columns]

# %%
# COMMENTS_DISABLED
df['comments_disabled'].value_counts(normalize=True)
# Out:
# False    0.983027
# True     0.016973
# Name: comments_disabled, dtype: float64

# %%
# RATINGS_DISABLED
df['ratings_disabled'].value_counts(normalize=True)
# Out:
# False    0.994887
# True     0.005113
# Name: ratings_disabled, dtype: float64

# %%
# VIDEO_ERROR_OR_REMOVED
df['video_error_or_removed'].value_counts(normalize=True)
# Out:
# False    0.999371
# True     0.000629
# Name: video_error_or_removed, dtype: float64

# %%
# DESCRIPTION

missing_description = df[df.description.isnull()]
print(f"How many missing value in description column? { len(missing_description) } ")
print(f"How many videos miss description? { len(missing_description.video_id.unique()) } ")
# Out:
# How many missing value in description column? 627
# How many videos miss description? 107

# %%
###### [ARCHIVED - One time used only] ############
## covnert topic_id text to csv
# with open("C:\\Users\\George\\Desktop\\coding-ground\\Youtube-analysis\\reference\\test.txt", "r") as file:
#     file = file.readlines()

# for line in file:
#     seperated = line.split(" ", 1)
#     seperated[1] = seperated[1].replace("\n", "")
#     joined = ",".join(seperated)
    
#     with open("C:\\Users\\George\\Desktop\\coding-ground\\Youtube-analysis\\reference\\topic_ids.csv", "a") as output:
#         output.write(joined + "\n")

# %%
###### [ARCHIVED - One time used only] ############
## format category id

# category_r_raw = pd.read_csv("reference/test.csv", sep="\t")

# category_r_raw = category_r_raw.rename(columns={"ID": "category_id", "CATEGORY NAME": "category_name", "CATEGORY DETAIL": "category_detail"})

# category_r_raw.to_csv("reference/category_ids.csv", index=False)
